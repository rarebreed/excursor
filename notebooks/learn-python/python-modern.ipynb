# %% [markdown]
# # Modern python 101
#
# We will go over new features since python 3.9 and also cover new features in the upcoming 3.12 that will come out later
# in 2023.  Some of these feeatures are not only brand new to python, but if you are not familiar with functional
# programming languages may be totally new to you.
#
# A separate guide on python type annotations in in the python-types.ipynb notebook and should be the first notebook
# that you read since it covers some basic python for those brand new to the python language.  We will cover the following:
#
# | version | feature                  |
# |---------|--------------------------|
# | 3.8     | types: Protocols         |
# | 3.9     | f strings                |
# | 3.9     | asyncio                  |
# | 3.10    | union types              |
# | 3.10    | pattern matching         |
# | 3.10    | types: Paramspec         |
# | 3.11    | types: Self              |
# | 3.11    | types: Variadic Generic  |
# | 3.12    | types: PEP-695           |
#
#
# No language is complete without an ecosystem of dev tools
#
#
# | name            | purpose           |
# |-----------------|-------------------|
# | poetry          | project manaer
# | autopep8        | formatter
# | ruff            | linter
# | pre-commit      | git hook
# | pytest          | test framework
# | pyinstrument    | cpu profiler
# | memray          | memory profiler
#
#
# Lastly will also cover some useful python frameworks
#
# | name           | purpose                    |
# | ---------------|----------------------------|
# | ray            | distributed compute/async
# | duckdb         | sql/dataframe
# | polars         | dataframe
# | pyarrow        | low-level arrow IO
# | boto3          | aws sdk
# | numpy          | math
# | pytorch        | general purpose ML
# | transformers   | NLP
# | datasets       | LLM and data sets
# | aiohttp        | async http client/server
# | plotly         | notebook visualization
# | py03           | rust native modules
# | maturin        | deploy native modules
# | fastapi        | web services
